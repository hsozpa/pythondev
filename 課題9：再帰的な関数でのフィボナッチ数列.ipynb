# %%
from prognum import fibonacci

num = int(input("何番目の数値を求めますか？："))


print(f"何番目の数値を求めますか？：{num}")
print(fibonacci(num))
# Out:
# 何番目の数値を求めますか？：8
# 21

# %%
from prognum import fibonacci

num = int(input("何番目の数値を求めますか？："))


print(f"何番目の数値を求めますか？：{num}")
print(fibonacci(num))
# Out:
# 何番目の数値を求めますか？：9
# 34

# %%
from prognum import fibonacci

num = int(input("何番目の数値を求めますか？："))


print(f"何番目の数値を求めますか？：{num}")
print(fibonacci(num))
# Out:
# 何番目の数値を求めますか？：10
# 55
